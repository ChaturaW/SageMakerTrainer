# %% [markdown]
# # Text Embedding: How to run inference on the endpoint you have created?

# %%
import json
import boto3

# %% [markdown]
# Let's put in some example input text. You can put in any text and the model will provide a single, fixed-length embedding vector for each input text.

# %%
text1 = "How cute your dog is!"
text2 = "Your dog is so cute."
text3 = "The mitochondria is the powerhouse of the cell."

# %% [markdown]
# ### Query endpoint that you have created
# You can query the endpoint with a batch of input texts within a json payload. Here, we send a single request to the endpoint and the parsed response is a list of the embedding vectors.

# %%
newline, bold, unbold = '\n', '\033[1m', '\033[0m'
endpoint_name = 'hf-textembedding-all-minilm-l6-v2'


def query_endpoint_with_json_payload(encoded_json):
    client = boto3.client('runtime.sagemaker')
    response = client.invoke_endpoint(EndpointName=endpoint_name, ContentType='application/json', Body=encoded_json)
    return response


def parse_response_multiple_texts(query_response):
    model_predictions = json.loads(query_response['Body'].read())
    embeddings = model_predictions['embedding']
    return embeddings


payload = {"text_inputs": [text1, text2, text3]}
query_response = query_endpoint_with_json_payload(json.dumps(payload).encode('utf-8'))
embeddings = parse_response_multiple_texts(query_response)

# %%
print(embeddings)
# Out:
# [[-0.01781977154314518, -0.015948351472616196, 0.028173338621854782, 0.046047914773225784, -0.0474776066839695, -0.01569276489317417, 0.0450027659535408, -0.041008852422237396, 0.0006518607260659337, 0.07065227627754211, 0.006733237765729427, -0.07180780917406082, 0.05573594942688942, 0.035677824169397354, -0.011766164563596249, -0.003018150106072426, -0.009817303158342838, -0.038815710693597794, -0.010179970413446426, -0.030514847487211227, -0.04384259507060051, 0.010275625623762608, 0.02319442480802536, 0.009290186688303947, -0.07263608276844025, -0.011316714808344841, 0.05693203955888748, -0.05303441360592842, 0.012029238976538181, -0.029316814616322517, -0.08560483157634735, -0.004702771082520485, -0.002175121335312724, 0.02074815332889557, -0.04623035714030266, -0.05631779134273529, 0.0529341846704483, 0.003416671184822917, 0.043462082743644714, 0.04935873672366142, -0.006095400545746088, 0.017440060153603554, 0.03804982826113701, -0.04161299020051956, -0.027987677603960037, -0.02925899066030979, -0.03367425873875618, -0.027935972437262535, -0.007901634089648724, 0.04946810379624367, -0.08663912862539291, 0.009183401241898537, 0.007641323376446962, 0.01097598485648632, -0.07554694265127182, -0.016039635986089706, -0.019403580576181412, -0.031281016767024994, 0.01901071146130562, -0.002974552335217595, -0.0031426534987986088, 0.1354377120733261, 0.01809537783265114, -0.005662449169903994, 0.04865657165646553, -0.07498154044151306, -0.026507649570703506, -0.02331225574016571, -0.03068525716662407, 0.011104296892881393, 0.02269134856760502, 0.08078388124704361, 0.016475772485136986, -0.000119251839350909, -0.005489499308168888, -0.05696164816617966, 0.033155642449855804, 0.01013733260333538, 0.09333337843418121, 0.06023278087377548, -0.058949146419763565, -0.07771112769842148, -0.0016121289227157831, 0.06249270588159561, 0.01894327439367771, -0.10943255573511124, -0.007009202614426613, -0.005628244951367378, -0.045566342771053314, -0.0008847735007293522, 0.017858827486634254, -0.024803481996059418, -0.05946889892220497, -0.018376605585217476, -0.028643786907196045, 0.015825515612959862, 0.030458752065896988, -0.08700405806303024, -0.07901173830032349, 0.026694027706980705, -0.01026227418333292, 0.003987085074186325, 0.0396682433784008, 0.01401655375957489, 0.0670613944530487, 0.05882030725479126, -0.013355549424886703, 0.022738654166460037, 0.0067245811223983765, -0.05675762891769409, 0.03579474613070488, -0.05757537856698036, 0.00453892070800066, 0.020694270730018616, 0.09447503089904785, -0.03222760185599327, -0.06031214818358421, -0.006274765823036432, 0.0010789610678330064, -0.05669134110212326, 0.03449347987771034, 0.028783468529582024, -0.05717167630791664, 0.0028589959256350994, -0.019981035962700844, -0.028151297941803932, 0.011373128741979599, -3.750768476629709e-33, -0.012108485214412212, 0.06796856224536896, -0.022822730243206024, 0.014347264543175697, 0.02964896894991398, -0.03631819039583206, -0.05223478376865387, -0.05443834513425827, -0.12013004720211029, -0.018748920410871506, 0.0013344830367714167, 0.00198647053912282, -0.028472930192947388, 0.03325021639466286, -0.02459457702934742, 0.0458509661257267, -0.059577129781246185, -0.024002453312277794, 0.08179156482219696, 0.09611836820840836, -0.0026809920091181993, -0.03203611448407173, 0.019627239555120468, 0.038510892540216446, 0.04081195592880249, -0.05246352031826973, -0.04722629860043526, -0.08789315074682236, -0.07394005358219147, 0.015395312570035458, 0.04501533508300781, 0.07415175437927246, 0.030077314004302025, 0.007329295389354229, -0.10567807406187057, -0.13220590353012085, -0.0682634487748146, -0.07653220742940903, -0.0015981969190761447, 0.12304443120956421, 0.14570413529872894, -0.07291451096534729, 0.056638188660144806, -0.01927136443555355, -0.08171521127223969, -0.01007130742073059, -0.03636525943875313, 0.030676499009132385, 0.024687346071004868, -0.029324844479560852, 0.05476278066635132, -0.0053377714939415455, 0.08201595395803452, -0.0269 ...
